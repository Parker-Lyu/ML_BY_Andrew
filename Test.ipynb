# %%
import numpy as np

# %%
aa = np.array([[1],[2],[3],[4]])
aa
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
aa[1]
# Out:
# array([2])

# %%
aa[1][0]
# Out:
# 2

# %%
cc = np.squeeze(aa)
cc
# Out:
# array([1, 2, 3, 4])

# %%
aa = np.array([[1, 2],
              [3, 4]])
aa
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
cc = np.linalg.inv(aa)
cc
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
np.matmul(aa,cc)
# Out:
# array([[1.00000000e+00, 1.11022302e-16],
#        [0.00000000e+00, 1.00000000e+00]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(dpi=100)
ax = Axes3D(fig)     #生成一个3d对象
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)    #对X,Y数组进行扩充
R = np.sqrt(X**2+Y**2)
Z = np.sin(R)
ax.set_xlabel('X label',color='r') #设置x坐标
ax.set_ylabel('Y label',color='r')
ax.set_zlabel('Z label')
ax.set_zlim(-2,2)#设置z的范围
ax.plot_surface(X, Y, Z,rstride=1,cstride=1,cmap=plt.cm.hot)#生成一个曲面   cmap = plt.get_cmap('rainbow')
ax.contourf(X,Y,Z,offset=-2,alpha=0.75,cmap=plt.cm.hot)#为等高线填充颜色
# ax.contour(X, Y, Z, offset=-2, colors='black')#生成等高线 offset参数是等高线所处的位置
 
fig=plt.figure(2,dpi=100)
 
bx=fig.gca()
 
C=bx.contour(X,Y,Z) #如果想要在等高线上标出相应的值，需要重新生成一个对象，不能是3d对象
bx.clabel(C,inline=True,fontsize=10) #在等高线上标出对应的z值
plt.show()

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import scipy as sp

# %%
iris = datasets.load_iris().data[:,1]
iris
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
#        3. , 4. , 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3. ,
#        3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.1, 3. ,
#        3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3. , 3.8, 3.2, 3.7, 3.3, 3.2, 3.2,
#        3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2. , 3. , 2.2, 2.9, 2.9,
#        3.1, 3. , 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3. , 2.8, 3. ,
#        2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3. , 3.4, 3.1, 2.3, 3. , 2.5, 2.6,
#        3. , 2.6, 2.3, 2.7, 3. , 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3. , 2.9,
#        3. , 3. , 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3. , 2.5, 2.8, 3.2, 3. ,
#        3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3. , 2.8, 3. ,
#        2.8, 3.8, 2.8, 2.8, 2.6, 3. , 3.4, 3.1, 3. , 3.1, 3.1, 3.1, 2.7,
#        3.2, 3.3, 3. , 2.5, 3. , 3.4, 3. ])

# %%
bins, scaler = np.histogram(iris, bins=20)
print(bins)
print(scaler)
# Out:
# [ 1  3  4  3  8 14 14 10 26 12 19 12  6  3  9  2  1  1  1  1]
# [2.   2.12 2.24 2.36 2.48 2.6  2.72 2.84 2.96 3.08 3.2  3.32 3.44 3.56
#  3.68 3.8  3.92 4.04 4.16 4.28 4.4 ]

# %%
scaler_deals = (scaler[1:] + scaler[:-1]) * 0.5
plt.bar(scaler_deals, bins,edgecolor='b',width=0.1)
plt.show()

# %%
plt.hist(iris, bins=50)
plt.show()

# %%
face = sp.misc.face()
plt.imshow(face)
plt.show()

# %%
color_ = ['r','g','b']
for i in range(3):
    channel = face[:,:,i].flatten()
    fig = plt.figure()
    plt.hist(channel,bins=256,color=color_[i],hold=1)
plt.show()
# Out:
# D:\Software\Anaconda\envs\pyDL\lib\site-packages\matplotlib\pyplot.py:3126: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
