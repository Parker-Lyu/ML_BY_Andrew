# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %% [markdown]
# ## 生成房价数据

# %%
# 面积
areas = np.random.randint(100,1000,size=100)
areas
# Out:
# array([789, 332, 210, 298, 606, 432, 138, 257, 204, 108, 554, 732, 640,
#        279, 945, 790, 202, 354, 938, 122, 870, 705, 202, 231, 930, 585,
#        141, 417, 827, 261, 382, 107, 810, 314, 456, 451, 896, 213, 370,
#        549, 236, 981, 736, 986, 706, 562, 700, 692, 680, 680, 921, 588,
#        473, 186, 966, 480, 684, 162, 648, 642, 621, 194, 259, 542, 995,
#        111, 751, 983, 304, 867, 990, 157, 857, 864, 926, 404, 212, 169,
#        648, 784, 959, 907, 668, 389, 690, 534, 162, 142, 867, 448, 446,
#        456, 903, 655, 242, 622, 348, 333, 919, 237])

# %%
# 线性函数的参数
a = 0.4
b = 100
# 噪音
noises = np.random.random(100)*200

# %%
# 房价
prices = areas * a + b + noises
plt.figure(figsize=(10,8))
plt.scatter(areas, prices)
plt.title(r'房价散点图')
plt.ylim(0,800)
plt.show()

# %% [markdown]
# ## 梯度下降，求线性函数参数值

# %%
# 初始化两个参数及设置学习率
A = 10.
B = 10.
lr = 0.000001
for i in range(30):
    #计算房价
    calcu_prices = A * areas + B
    # 计算代价函数
    cost = (np.square(calcu_prices - prices)).mean() * 0.5
    # 计算更正量
    deltA = ((calcu_prices-prices)*areas).mean()
    deltB = (calcu_prices-prices).mean()
    A = A - lr*deltA
    B = B - lr*deltB
    print("Itera:{:<3d} ,cost:{:<15.4f}, A:{:<.4f}, B:{:<.4f}".format(i, cost, A, B))
# Out:
# Itera:0   ,cost:15977306.8610  , A:6.5685, B:9.9950
# Itera:1   ,cost:6372358.8789   , A:4.4019, B:9.9919
# Itera:2   ,cost:2543638.4228   , A:3.0341, B:9.9899
# Itera:3   ,cost:1017435.4320   , A:2.1704, B:9.9887
# Itera:4   ,cost:409061.0159    , A:1.6252, B:9.9880
# Itera:5   ,cost:166551.0527    , A:1.2809, B:9.9875
# Itera:6   ,cost:69881.8288     , A:1.0636, B:9.9872
# Itera:7   ,cost:31347.5810     , A:0.9263, B:9.9871
# Itera:8   ,cost:15987.0738     , A:0.8397, B:9.9870
# Itera:9   ,cost:9864.0735      , A:0.7850, B:9.9869
# Itera:10  ,cost:7423.3246      , A:0.7505, B:9.9869
# Itera:11  ,cost:6450.3931      , A:0.7287, B:9.9869
# Itera:12  ,cost:6062.5625      , A:0.7149, B:9.9870
# Itera:13  ,cost:5907.9645      , A:0.7062, B:9.9870
# Itera:14  ,cost:5846.3377      , A:0.7007, B:9.9870
# Itera:15  ,cost:5821.7709      , A:0.6973, B:9.9871
# Itera:16  ,cost:5811.9770      , A:0.6951, B:9.9871
# Itera:17  ,cost:5808.0719      , A:0.6937, B:9.9872
# Itera:18  ,cost:5806.5141      , A:0.6928, B:9.9872
# Itera:19  ,cost:5805.8921      , A:0.6923, B:9.9872
# Itera:20  ,cost:5805.6430      , A:0.6919, B:9.9873
# Itera:21  ,cost:5805.5427      , A:0.6917, B:9.9873
# Itera:22  ,cost:5805.5016      , A:0.6916, B:9.9874
# Itera:23  ,cost:5805.4841      , A:0.6915, B:9.9874
# Itera:24  ,cost:5805.4760      , A:0.6914, B:9.9874
# Itera:25  ,cost:5805.4717      , A:0.6914, B:9.9875
# Itera:26  ,cost:5805.4689      , A:0.6914, B:9.9875
# Itera:27  ,cost:5805.4667      , A:0.6913, B:9.9876
# Itera:28  ,cost:5805.4648      , A:0.6913, B:9.9876
# Itera:29  ,cost:5805.4629      , A:0.6913, B:9.9877

# %% [markdown]
# ## 拟合结果

# %%
pre_prices = A * areas + B
plt.figure(figsize=(10,8))
plt.scatter(areas, prices)
plt.plot(areas, pre_prices,'r-')
plt.ylim(0,800)
plt.show()
